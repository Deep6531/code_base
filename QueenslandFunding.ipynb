# %% [markdown]
# <a href="https://colab.research.google.com/github/Deep6531/code_base/blob/master/QueenslandFunding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Complete the following cell with your details and run to produce your personalised header for this assignment

from IPython.display import HTML

first_name = 'Saideep'
last_name = 'Kambhampati'
student_number = 'n11355832'

personal_header = f"<h1>{first_name} {last_name} ({student_number})</h1>"
HTML(personal_header)
# Out:
# <h1>Saideep Kambhampati (n11355832)</h1>

# %%
import pandas as pd

#  file path
file1 = '/content/advance-queensland-funding-recipients.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file1, encoding = "ISO-8859-1")

df
# Out:
#                                                 Program  \
# 0     Aboriginal and Torres Strait Islander PhD Scho...
# 1     Aboriginal and Torres Strait Islander PhD Scho...
# 2     Aboriginal and Torres Strait Islander Research...
# 3     Aboriginal and Torres Strait Islander Research...
# 4                 Advancing Regional Innovation Program
# ...                                                 ...
# 1334                               Young Starters' Fund
# 1335                               Young Starters' Fund
# 1336                               Young Starters' Fund
# 1337                               Young Starters' Fund
# 1338                               Young Starters' Fund
#
#                                                  Round   \
# 0     AQ Aboriginal & Torres Strait Islander PhD Sch...
# 1     AQ Aboriginal & Torres Strait Islander PhD Sch...
# 2     AQ Aboriginal & Torres Strait Islander Researc...
# 3     AQ Aboriginal & Torres Strait Islander Researc...
# ...

# %%
df.head()
# Out:
#                                              Program  \
# 0  Aboriginal and Torres Strait Islander PhD Scho...
# 1  Aboriginal and Torres Strait Islander PhD Scho...
# 2  Aboriginal and Torres Strait Islander Research...
# 3  Aboriginal and Torres Strait Islander Research...
# 4              Advancing Regional Innovation Program
#
#                                               Round   \
# 0  AQ Aboriginal & Torres Strait Islander PhD Sch...
# 1  AQ Aboriginal & Torres Strait Islander PhD Sch...
# 2  AQ Aboriginal & Torres Strait Islander Researc...
# 3  AQ Aboriginal & Torres Strait Islander Researc...
# 4      AQ Advancing Regional Innovation Full 2016-17
#
#                         Recipient Name  \
# 0        Central Queensland University
# 1                  Griffith University
# 2  Queensland University of Technology
# 3                                CSIRO
# 4                 Redland City Council
#
#   Physical Address of Recipient - Suburb/Location  \
# ...

# %%
df.set_index('Recipient Name', inplace=True)
df
# Out:
#                                                                                         Program  \
# Recipient Name
# Central Queensland University                 Aboriginal and Torres Strait Islander PhD Scho...
# Griffith University                           Aboriginal and Torres Strait Islander PhD Scho...
# Queensland University of Technology           Aboriginal and Torres Strait Islander Research...
# CSIRO                                         Aboriginal and Torres Strait Islander Research...
# Redland City Council                                      Advancing Regional Innovation Program
# ...                                                                                         ...
# Griffith University                                                        Young Starters' Fund
# Fifty Six Creations Pty Ltd - Mt Gravatt                                   Young Starters' Fund
# South Bank Business Association Incorporated                               Young Starters' Fund
# ...

# %%
df.dtypes
# Out:
# Program                                                    object
# Round                                                      object
# Physical Address of Recipient - Suburb/Location            object
# Physical Address of Recipient - Post Code                 float64
# University Collaborator (if applicable)                    object
# Other Partners; Collaborators (if applicable)              object
# Investment/Project Title                                   object
# Primary Location of Activity/Project - Suburb              object
# Primary Location of Activity/Project - Post Code          float64
# Multiple Locations of Activity/Project (if applicable)     object
# Local Government /Council                                  object
# RAP Region                                                 object
# State Electorate                                           object
# Actual Contractual Commitment ($)                          object
# dtype: object

# %%
# Assuming your DataFrame is named df
# Convert the "Actual Contractual Commitment ($)" column to numeric if it's not already
df['Actual Contractual Commitment ($)'] = pd.to_numeric(df['Actual Contractual Commitment ($)'], errors='coerce')

# Group the DataFrame by the "Program" column and calculate the sum of the funding amounts
total_funding_per_program = df.groupby('Program')['Actual Contractual Commitment ($)'].sum()

# Print the result
print(total_funding_per_program)
# Out:
# Program
# Aboriginal and Torres Strait Islander PhD Scholarships          224584.0
# Aboriginal and Torres Strait Islander Research Fellowships      398032.0
# Advancing Regional Innovation Program                          6251683.0
# Agtech and Logistics Hub                                       3000000.0
# Artificial Intelligence Hub                                    5000000.0
#                                                                  ...
# UQ - COVID-19 Vaccine                                         10000000.0
# WaterStart                                                      500000.0
# Yarrabah Business Accelerator Incubation Hub                    300000.0
# Young Starters' Competition                                      90000.0
# Young Starters' Fund                                            656555.0
# Name: Actual Contractual Commitment ($), Length: 81, dtype: float64

# %%
# Assuming 'total_funding_per_program' is the Series containing the grouped data
# Convert the Series to a DataFrame
grouped_data_df = total_funding_per_program.reset_index()
grouped_data_df.columns = ['Program', 'Total Funding']

# Save the DataFrame as a CSV file
grouped_data_df.to_csv('total_funding_per_program.csv', index=False)

# Print a message to confirm that the file has been saved
print("Data saved successfully.")
# Out:
# Data saved successfully.

# %%
import matplotlib.pyplot as plt

# Plot the grouped data as a bar plot
plt.figure(figsize=(12, 8))
plt.bar(grouped_data_df['Program'], grouped_data_df['Total Funding'])

# Add labels and title
plt.xlabel('Program')
plt.ylabel('Total Funding ($)')
plt.title('Total Funding Amount for Each Program')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Show plot
plt.tight_layout()
plt.show()
